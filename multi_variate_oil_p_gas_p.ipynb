# %%
import pandas as pd
from datetime import date
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import MinMaxScaler
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout,LSTM,Activation,RepeatVector
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import tensorflow as tf

# %%
df = pd.read_csv('mgasoil.txt', sep=' ')

# %%
df.head()
# Out:
#    year  mon   Greg   hoil    oilp  gasp
# 0  1993   11  1.066  0.502  16.699  2.32
# 1  1993   12  1.014  0.435  14.510  2.09
# 2  1994    1  0.998  0.499  15.000  2.41
# 3  1994    2  1.009  0.557  14.780  2.59
# 4  1994    3  1.008  0.492  14.660  2.08

# %%
df['Date'] = df['year'].astype(str)+' /'+df['mon'].astype(str)

# %%
df_new = df[['Date', 'oilp','gasp']]
df_new
# Out:
#          Date     oilp  gasp
# 0    1993 /11   16.699  2.32
# 1    1993 /12   14.510  2.09
# 2     1994 /1   15.000  2.41
# 3     1994 /2   14.780  2.59
# 4     1994 /3   14.660  2.08
# ..        ...      ...   ...
# 221   2012 /4  103.330  1.95
# 222   2012 /5   94.700  2.43
# 223   2012 /6   82.410  2.46
# 224   2012 /7   87.930  2.96
# 225   2012 /8   94.160  2.84
#
# [226 rows x 3 columns]

# %%
data_set = df_new[['oilp','gasp']]
data_set
# Out:
#         oilp  gasp
# 0     16.699  2.32
# 1     14.510  2.09
# 2     15.000  2.41
# 3     14.780  2.59
# 4     14.660  2.08
# ..       ...   ...
# 221  103.330  1.95
# 222   94.700  2.43
# 223   82.410  2.46
# 224   87.930  2.96
# 225   94.160  2.84
#
# [226 rows x 2 columns]

# %%
#Normalizing the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_dataset = scaler.fit_transform(data_set)
scaled_dataset.shape
# Out:
# (226, 2)

# %%
def create_dataset(scaled_data):
    window_size = 6
    x_set =[]
    y_set =[]
    
    for i in range(window_size,len(scaled_data)):
        x_set.append(scaled_data[i-window_size:i,:])
        y_set.append(scaled_data[i,0:1])
        
    return x_set, y_set

# %%
#get the x data and y data 
x_set, y_set = create_dataset(scaled_dataset)
x_data = np.array(x_set)
y_data = np.array(y_set)
print(x_data.shape)
print(y_data.shape)
# Out:
# (220, 6, 2)
# (220, 1)

# %%
#Split data
#x_data
train_size = int(len(x_data)*0.8)
test_size_x = len(x_data) - train_size
train_data_x = x_data[:train_size]
test_data_x =  x_data[train_size:]

print(train_data_x.shape)
print(test_data_x.shape)

#y_data
train_size = int(len(y_data)*0.8)
test_size_y = len(y_data) - train_size
train_data_y = y_data[:train_size]
test_data_y =  y_data[train_size:]
print(train_data_y.shape)
print(test_data_y.shape)
# Out:
# (176, 6, 2)
# (44, 6, 2)
# (176, 1)
# (44, 1)

# %%
train_data_x.shape[1]
train_data_x.shape[2]
# Out:
# 2

# %%
model = Sequential()

model.add(LSTM(units = 512, return_sequences = True, input_shape=(train_data_x.shape[1], train_data_x.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(units = 256, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 256, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 256))
model.add(Dropout(0.2))

model.add(Dense(units = 1))


model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
#model fit
history = model.fit(train_data_x, train_data_y, epochs = 200, batch_size=80)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 6s 125ms/step - loss: 0.0784
# Epoch 2/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0309
# Epoch 3/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0220
# Epoch 4/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0241
# Epoch 5/200
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0130
# Epoch 6/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0155
# Epoch 7/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0142
# Epoch 8/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0120
# Epoch 9/200
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0137
# Epoch 10/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0083
# Epoch 11/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0098
# Epoch 12/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0085
# Epoch 13/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0086
# Epoch 14/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0080
# Epoch 15/200
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0090
# Epoch 16/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0109
# Epoch 17/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0078
# Epoch 18/200
# 3/3 [==============================] - 1s 152ms/step - loss: 0.0111
# Epoch 19/200
# 3/3 [==============================] - 0s 149ms/step - loss: 0.0071
# Epoch 20/200
# 3/3 [==============================] - 1s 152ms/step - loss: 0.0109
# Epoch 21/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0087
# Epoch 22/200
# 3/3 [==============================] - 1s 151ms/step - loss: 0.0129
# Epoch 23/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0094
# Epoch 24/200
# 3/3 [==============================] - 1s 153ms/step - loss: 0.0095
# Epoch 25/200
# 3/3 [==============================] - 1s 151ms/step - loss: 0.0081
# Epoch 26/200
# 3/3 [==============================] - 1s 153ms/step - loss: 0.0097
# Epoch 27/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0078
# Epoch 28/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0097
# Epoch 29/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0079
# Epoch 30/200
# 3/3 [==============================] - 1s 150ms/step - loss: 0.0134
# Epoch 31/200
# 3/3 [==============================] - 1s 165ms/step - loss: 0.0092
# Epoch 32/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0107
# Epoch 33/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0088
# Epoch 34/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0101
# Epoch 35/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0078
# Epoch 36/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0093
# Epoch 37/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0067
# Epoch 38/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0078
# Epoch 39/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0079
# Epoch 40/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0080
# Epoch 41/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0074
# Epoch 42/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0067
# Epoch 43/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0075
# Epoch 44/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0070
# Epoch 45/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0082
# Epoch 46/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0067
# Epoch 47/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0068
# Epoch 48/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0082
# Epoch 49/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0084
# Epoch 50/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0090
# Epoch 51/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0095
# Epoch 52/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0135
# Epoch 53/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0082
# Epoch 54/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0103
# Epoch 55/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0071
# Epoch 56/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0091
# Epoch 57/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0070
# Epoch 58/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0076
# Epoch 59/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0071
# Epoch 60/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0070
# Epoch 61/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0070
# Epoch 62/200
# 3/3 [==============================] - 1s 165ms/step - loss: 0.0085
# Epoch 63/200
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0068
# Epoch 64/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0088
# Epoch 65/200
# 3/3 [==============================] - 1s 165ms/step - loss: 0.0080
# Epoch 66/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0071
# Epoch 67/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0071
# Epoch 68/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0066
# Epoch 69/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0074
# Epoch 70/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0073
# Epoch 71/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0078
# Epoch 72/200
# 3/3 [==============================] - 1s 165ms/step - loss: 0.0093
# Epoch 73/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0101
# Epoch 74/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0071
# Epoch 75/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0073
# Epoch 76/200
# 3/3 [==============================] - 1s 165ms/step - loss: 0.0066
# Epoch 77/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0065
# Epoch 78/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0062
# Epoch 79/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0059
# Epoch 80/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0065
# Epoch 81/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0073
# Epoch 82/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0102
# Epoch 83/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0079
# Epoch 84/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0071
# Epoch 85/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0079
# Epoch 86/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0064
# Epoch 87/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0077
# Epoch 88/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0070
# Epoch 89/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0085
# Epoch 90/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0069
# Epoch 91/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0066
# Epoch 92/200
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0062
# Epoch 93/200
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0058
# Epoch 94/200
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0047
# Epoch 95/200
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0055
# Epoch 96/200
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0068
# Epoch 97/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0046
# Epoch 98/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0045
# Epoch 99/200
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0040
# Epoch 100/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0039
# Epoch 101/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0037
# Epoch 102/200
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0033
# Epoch 103/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0076
# Epoch 104/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0053
# Epoch 105/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0039
# Epoch 106/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0041
# Epoch 107/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0042
# Epoch 108/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0033
# Epoch 109/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0029
# Epoch 110/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0033
# Epoch 111/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0080
# Epoch 112/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0055
# Epoch 113/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0061
# Epoch 114/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0052
# Epoch 115/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0042
# Epoch 116/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0071
# Epoch 117/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0038
# Epoch 118/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0065
# Epoch 119/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0071
# Epoch 120/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0090
# Epoch 121/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0054
# Epoch 122/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0058
# Epoch 123/200
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0065
# Epoch 124/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0095
# Epoch 125/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0060
# Epoch 126/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0063
# Epoch 127/200
# 3/3 [==============================] - 1s 165ms/step - loss: 0.0045
# Epoch 128/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0037
# Epoch 129/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0041
# Epoch 130/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0027
# Epoch 131/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0029
# Epoch 132/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0026
# Epoch 133/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0026
# Epoch 134/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0027
# Epoch 135/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0027
# Epoch 136/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0020
# Epoch 137/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0021
# Epoch 138/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0023
# Epoch 139/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0036
# Epoch 140/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0031
# Epoch 141/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0027
# Epoch 142/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0021
# Epoch 143/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0017
# Epoch 144/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0021
# Epoch 145/200
# 3/3 [==============================] - 1s 152ms/step - loss: 0.0020
# Epoch 146/200
# 3/3 [==============================] - 1s 151ms/step - loss: 0.0021
# Epoch 147/200
# 3/3 [==============================] - 1s 155ms/step - loss: 0.0023
# Epoch 148/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0016
# Epoch 149/200
# 3/3 [==============================] - 1s 153ms/step - loss: 0.0023
# Epoch 150/200
# 3/3 [==============================] - 1s 152ms/step - loss: 0.0022
# Epoch 151/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0017
# Epoch 152/200
# 3/3 [==============================] - 1s 173ms/step - loss: 0.0025
# Epoch 153/200
# 3/3 [==============================] - 1s 173ms/step - loss: 0.0031
# Epoch 154/200
# 3/3 [==============================] - 1s 177ms/step - loss: 0.0026
# Epoch 155/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0028
# Epoch 156/200
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0034
# Epoch 157/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0020
# Epoch 158/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0041
# Epoch 159/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0017
# Epoch 160/200
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0020
# Epoch 161/200
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0017
# Epoch 162/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0023
# Epoch 163/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0017
# Epoch 164/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0028
# Epoch 165/200
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0024
# Epoch 166/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0022
# Epoch 167/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0015
# Epoch 168/200
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0028
# Epoch 169/200
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0024
# Epoch 170/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0018
# Epoch 171/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0015
# Epoch 172/200
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0017
# Epoch 173/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0015
# Epoch 174/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0021
# Epoch 175/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0017
# Epoch 176/200
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0018
# Epoch 177/200
# 3/3 [==============================] - 1s 175ms/step - loss: 0.0020
# Epoch 178/200
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0022
# Epoch 179/200
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0023
# Epoch 180/200
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0018
# Epoch 181/200
# 3/3 [==============================] - 1s 178ms/step - loss: 0.0018
# Epoch 182/200
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0015
# Epoch 183/200
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0020
# Epoch 184/200
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0019
# Epoch 185/200
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0015
# Epoch 186/200
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0017
# Epoch 187/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0016
# Epoch 188/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0019
# Epoch 189/200
# 3/3 [==============================] - 1s 275ms/step - loss: 0.0021
# Epoch 190/200
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0016
# Epoch 191/200
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0018
# Epoch 192/200
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0016
# Epoch 193/200
# 3/3 [==============================] - 1s 180ms/step - loss: 0.0016
# Epoch 194/200
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0014
# Epoch 195/200
# 3/3 [==============================] - 1s 171ms/step - loss: 0.0015
# Epoch 196/200
# 3/3 [==============================] - 1s 173ms/step - loss: 0.0022
# Epoch 197/200
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0016
# Epoch 198/200
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0012
# Epoch 199/200
# 3/3 [==============================] - 1s 173ms/step - loss: 0.0014
# Epoch 200/200
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0029

# %%
#Get predictions
y_predicted = model.predict(test_data_x)
#y_predicted
# Out:
# 2/2 [==============================] - 1s 15ms/step

# %%
test_data_y
# Out:
# array([[0.24834896],
#        [0.22731349],
#        [0.29922544],
#        [0.31398288],
#        [0.39037913],
#        [0.47615165],
#        [0.43057481],
#        [0.48740318],
#        [0.47435793],
#        [0.5262128 ],
#        [0.54463922],
#        [0.51381981],
#        [0.54578068],
#        [0.53110477],
#        [0.57040359],
#        [0.59682022],
#        [0.5100693 ],
#        [0.52238076],
#        [0.53069711],
#        [0.53436608],
#        [0.52205463],
#        [0.57578475],
#        [0.5940481 ],
#        [0.63399918],
#        [0.63709743],
#        [0.63840196],
#        [0.7473298 ],
#        [0.8052181 ],
#        [0.73420302],
#        [0.69311048],
#        [0.70044843],
#        [0.61190379],
#        [0.60603343],
#        [0.61255605],
#        [0.7006115 ],
#        [0.71169996],
#        [0.72531594],
#        [0.74170404],
#        [0.77382797],
#        [0.75050958],
#        [0.68014676],
#        [0.57994293],
#        [0.62494904],
#        [0.67574399]])

# %%
data = scaled_dataset[:44,:]
y_pred_act = np.concatenate((y_predicted,data[:44,1:]),axis=1)
y_test_act = np.concatenate((test_data_y,data[:44,1:]),axis=1)

# %%
#Calculate RMSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test_data_y, y_predicted)

rmse = np.sqrt(mse)
rmse
# Out:
# 0.05474799936398181

# %%
Y_tested = scaler.inverse_transform(y_test_act)
Y_predicted = scaler.inverse_transform(y_pred_act)

Y_predicted = Y_predicted[:,0:1]
Y_tested = Y_tested[:,0:1]
Y_tested.shape
# Out:
# (44, 1)

# %%
#Calculate RMSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_tested,Y_predicted)

rmse = np.sqrt(mse)
rmse
# Out:
# 6.714842121992368
